# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


with open('q1.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X, Y = zip(*[[float(s) for s in line.split()] for line in f])
    
plt.xlabel('Number of nodes')
plt.ylabel('Channel utilization rate')
plt.title('Question (a)')
plt.plot(X, Y)
plt.show()

# %%
with open('q2.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X, Y = zip(*[[float(s) for s in line.split()] for line in f])
    
plt.xlabel('Number of nodes')
plt.ylabel('Channel idle fraction')
plt.title('Question (b)')
plt.plot(X, Y)
plt.show()

# %%
with open('q3.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X, Y = zip(*[[float(s) for s in line.split()] for line in f])
    
plt.xlabel('Number of nodes')
plt.ylabel('Number of collisions')
plt.title('Question (c)')
plt.plot(X, Y)
plt.show()

# %%
with open('q4_1.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X1, Y1 = zip(*[[float(s) for s in line.split()] for line in f])
    
with open('q4_2.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X2, Y2 = zip(*[[float(s) for s in line.split()] for line in f])
    
with open('q4_3.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X3, Y3 = zip(*[[float(s) for s in line.split()] for line in f])

with open('q4_4.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X4, Y4 = zip(*[[float(s) for s in line.split()] for line in f])

with open('q4_5.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X5, Y5 = zip(*[[float(s) for s in line.split()] for line in f])

legend = ['R=1', 'R=2', 'R=4', 'R=8' , 'R=16']
plt.xlabel('Number of nodes')
plt.ylabel('Channel utilization rate')
plt.title('Question (d)')
plt.plot(X1, Y1)
plt.plot(X2, Y2)
plt.plot(X3, Y3)
plt.plot(X4, Y4)
plt.plot(X5, Y5)
plt.legend(legend)
plt.show()

# %%
with open('q5_1.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X1, Y1 = zip(*[[float(s) for s in line.split()] for line in f])
    
with open('q5_2.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X2, Y2 = zip(*[[float(s) for s in line.split()] for line in f])
    
with open('q5_3.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X3, Y3 = zip(*[[float(s) for s in line.split()] for line in f])

with open('q5_4.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X4, Y4 = zip(*[[float(s) for s in line.split()] for line in f])

with open('q5_5.txt') as f:
    #lines = f.readlines()
    #x = [line.split()[0] for line in lines]
    #y = [line.split()[1] for line in lines]
    X5, Y5 = zip(*[[float(s) for s in line.split()] for line in f])

legend = ['L=20', 'L=40', 'L=60', 'L=80' , 'L=100']
plt.xlabel('Number of nodes')
plt.ylabel('Channel utilization rate')
plt.title('Question (e)')
plt.plot(X1, Y1)
plt.plot(X2, Y2)
plt.plot(X3, Y3)
plt.plot(X4, Y4)
plt.plot(X5, Y5)
plt.legend(legend)
plt.show()
